# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def visualize_data(data):
    plt.rcParams["figure.figsize"] = (15,7)
    fig = plt.figure()
    ax = plt.subplot(111)
    for col in data.columns:
        ax.plot(data[col], label=col)
    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    plt.show()

# %%
nyse_o = pd.read_pickle("./data/nyse_o.pkl")
visualize_data(nyse_o)

# %%
nyse_n = pd.read_pickle("./data/nyse_n.pkl")
visualize_data(nyse_n)

# %%
djia = pd.read_pickle("./data/djia.pkl")
visualize_data(djia)

# %%
tse = pd.read_pickle("./data/tse.pkl")
visualize_data(tse)

# %%
sp500 = pd.read_pickle("./data/sp500.pkl")
visualize_data(sp500)

# %%
msci = pd.read_pickle("./data/msci.pkl")
visualize_data(msci)
